# %% [markdown]
# # 01 Dataset
#
# Load Brazil Glaucoma Database paths, resize images, normalize during model input, and create horizontal flip copies.

# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.data_loader import load_brg_dataset
from src.preprocess import preprocess_directory
from src.augmentation import duplicate_flipped_images
from src.utils import RAW_DIR, PROCESSED_DIR, MASK_DIR, ensure_dirs

ensure_dirs()
df = load_brg_dataset(RAW_DIR)
df.head()

# %%
print(df['label'].value_counts())
print(f'Total images: {len(df)}')

# %%
saved = preprocess_directory(RAW_DIR, PROCESSED_DIR)
print(f'Preprocessed images saved: {len(saved)}')

# %%
created = duplicate_flipped_images(PROCESSED_DIR, MASK_DIR)
print(f'Horizontal flip copies created: {len(created)}')
