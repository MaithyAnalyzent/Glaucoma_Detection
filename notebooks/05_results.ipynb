# %% [markdown]
# # 05 Results
#
# Review classification report, confusion matrix text, and generated training plots.

# %%
import sys
from pathlib import Path
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.utils import OUTPUT_DIR, PLOTS_DIR

report_path = OUTPUT_DIR / 'classification_report.txt'
if report_path.exists():
    print(report_path.read_text())
else:
    print('classification_report.txt has not been generated yet.')

# %%
for plot in sorted(PLOTS_DIR.glob('*.png')):
    print(plot.name)
    display(Image(filename=str(plot)))
