# %% [markdown]
# # 03 Fine Tune KFold
#
# Phase 2 fine tuning: unfreeze all layers of the contracting path/base model, run KFold cross validation with k=5, learning rate 5e-6, and 100 epochs.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.finetune import finetune_kfold

fold_scores = finetune_kfold(epochs=100, batch_size=8, learning_rate=5e-6, k=5)
fold_scores
