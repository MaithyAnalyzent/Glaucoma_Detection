# %% [markdown]
# # 02 U-Net Training
#
# Phase 1 pretraining for V-UNET V1.1 using VGG16 frozen encoder, learning rate 1e-5, 0.8 train-test split, and 100 epochs.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.unet_model import TL_unet_model

model = TL_unet_model((256, 256, 3))
model.summary()

# %%
from src.train_unet import pretrain_unet

model, history = pretrain_unet(epochs=100, batch_size=8, learning_rate=1e-5)
