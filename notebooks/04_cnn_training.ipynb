# %% [markdown]
# # 04 CNN Training
#
# Generate segmented images from the fine tuned U-Net and train the standard CNN classifier for 150 epochs.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.predict import load_unet, generate_segmented_dataset
from src.train_cnn import train_cnn
from src.utils import PROCESSED_DIR, SEGMENTED_DIR

unet = load_unet()
saved = generate_segmented_dataset(PROCESSED_DIR, unet, SEGMENTED_DIR)
print(f'Segmented images saved: {len(saved)}')

# %%
model, history = train_cnn(SEGMENTED_DIR, epochs=150, batch_size=16)
